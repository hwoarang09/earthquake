# %% [markdown]
# # Import Library

# %%
import flask
import dash
import vizro
import vizro.plotly.express as px

from vizro import Vizro
from vizro.models.types import capture
import vizro.models as vm
import pandas as pd
import numpy as np

from datetime import datetime
from datetime import datetime, date

# %% [markdown]
# # Data Load

# %%
path = r"C:\Users\hwoar\OneDrive\바탕 화면\sw_train\튜터알바\메가스터디 과외자료\현우\git\\"
koreafile = 'data_preprocessing.csv'
worldfile = 'df_worlds.csv'

# %%
#외국지진데이터
df_world = pd.read_csv(path+worldfile,
                       index_col = 'Date',  parse_dates=['Time', 'Date'])

df_world.index = pd.to_datetime(df_world.index, format='ISO')
df_world
# Out:
#                            Latitude  Longitude  Magnitude      Month  Year  \
# Date
# 1965-02-01 00:00:00+00:00   19.2460   145.6160        6.0   February  1965
# 1965-04-01 00:00:00+00:00    1.8630   127.3520        5.8      April  1965
# 1965-05-01 00:00:00+00:00  -20.5790  -173.9720        6.2        May  1965
# 1965-08-01 00:00:00+00:00  -59.0760   -23.5570        5.8     August  1965
# 1965-09-01 00:00:00+00:00   11.9380   126.4270        5.8  September  1965
# ...                             ...        ...        ...        ...   ...
# 2016-12-28 00:00:00+00:00   38.3917  -118.8941        5.6   December  2016
# 2016-12-28 00:00:00+00:00   38.3777  -118.8957        5.5   December  2016
# 2016-12-28 00:00:00+00:00   36.9179   140.4262        5.9   December  2016
# 2016-12-29 00:00:00+00:00   -9.0283   118.6639        6.3   December  2016
# 2016-12-30 00:00:00+00:00   37.3973   141.4103        5.5   December  2016
#
#                                           la_lo                 region  \
# Date
# 1965-02-01 00:00:00+00:00     [19.246, 145.616]         Philippine Sea
# 1965-04-01 00:00:00+00:00      [1.863, 127.352]            Molucca Sea
# 1965-05-01 00:00:00+00:00   [-20.579, -173.972]                  error
# 1965-08-01 00:00:00+00:00    [-59.076, -23.557]         Southern Ocean
# 1965-09-01 00:00:00+00:00     [11.938, 126.427]         Philippine Sea
# ...                                         ...                    ...
# 2016-12-28 00:00:00+00:00  [38.3917, -118.8941]          United States
# 2016-12-28 00:00:00+00:00  [38.3777, -118.8957]          United States
# 2016-12-28 00:00:00+00:00   [36.9179, 140.4262]                  Japan
# 2016-12-29 00:00:00+00:00   [-9.0283, 118.6639]                  error
# 2016-12-30 00:00:00+00:00   [37.3973, 141.4103]  Japan Full Region Sea
#
#                                                Time
# Date
# 1965-02-01 00:00:00+00:00 1965-02-01 00:00:00+00:00
# 1965-04-01 00:00:00+00:00 1965-04-01 00:00:00+00:00
# 1965-05-01 00:00:00+00:00 1965-05-01 00:00:00+00:00
# 1965-08-01 00:00:00+00:00 1965-08-01 00:00:00+00:00
# 1965-09-01 00:00:00+00:00 1965-09-01 00:00:00+00:00
# ...                                             ...
# 2016-12-28 00:00:00+00:00 2016-12-28 00:00:00+00:00
# 2016-12-28 00:00:00+00:00 2016-12-28 00:00:00+00:00
# 2016-12-28 00:00:00+00:00 2016-12-28 00:00:00+00:00
# 2016-12-29 00:00:00+00:00 2016-12-29 00:00:00+00:00
# 2016-12-30 00:00:00+00:00 2016-12-30 00:00:00+00:00
#
# [23232 rows x 8 columns]

# %%
#한국지진데이터
df_korea = pd.read_csv(path+koreafile, 
                 index_col = '발생시각',  parse_dates=['Time', '발생시각'])

df_korea = df_korea.rename(columns={'규모' : 'Magnitude', 'latitude' : 'Latitude', 'longitude' : 'Longitude'})
df_korea
# Out:
#                      Magnitude  Latitude  Longitude  지역  남북     도   시군  \
# 발생시각
# 1978-08-30 02:29:43        4.5     39.10     124.20  해역  북한  평안북도   철산
# 1978-09-16 02:07:06        5.2     36.60     127.90  지역  한국    경북  상주시
# 1978-10-07 18:19:52        5.0     36.60     126.70  지역  한국    충남  홍성군
# 1978-11-23 11:06:05        4.6     38.40     125.60  지역  북한  황해남도   안악
# 1978-12-04 15:16:16        2.8     37.40     128.70  지역  한국    강원  정선군
# ...                        ...       ...        ...  ..  ..   ...  ...
# 2024-12-22 08:05:55        2.4     33.68     125.15  해역  한국    전남  신안군
# 2024-12-25 21:16:45        2.1     35.11     125.07  해역  한국    전남  신안군
# 2024-12-27 09:43:10        2.9     41.31     129.13  지역  북한  함경북도   길주
# 2024-12-27 09:45:06        2.5     41.30     129.09  지역  북한  함경북도   길주
# 2024-12-27 11:14:27        2.7     41.31     129.12  지역  북한  함경북도   길주
#
#                          Month  Year Year_5년 단위                Time
# 발생시각
# 1978-08-30 02:29:43     August  1978  1978-1982 1978-08-30 02:29:43
# 1978-09-16 02:07:06  September  1978  1978-1982 1978-09-16 02:07:06
# 1978-10-07 18:19:52    October  1978  1978-1982 1978-10-07 18:19:52
# 1978-11-23 11:06:05   November  1978  1978-1982 1978-11-23 11:06:05
# 1978-12-04 15:16:16   December  1978  1978-1982 1978-12-04 15:16:16
# ...                        ...   ...        ...                 ...
# 2024-12-22 08:05:55   December  2024  2023-2027 2024-12-22 08:05:55
# 2024-12-25 21:16:45   December  2024  2023-2027 2024-12-25 21:16:45
# 2024-12-27 09:43:10   December  2024  2023-2027 2024-12-27 09:43:10
# 2024-12-27 09:45:06   December  2024  2023-2027 2024-12-27 09:45:06
# 2024-12-27 11:14:27   December  2024  2023-2027 2024-12-27 11:14:27
#
# [2248 rows x 11 columns]

# %%
df_korea['Year5'] = pd.cut(df_korea.index.year,
                          bins=range(df_korea.index.year.min(), df_korea.index.year.max() + 6, 5),
                          right=False,
                          labels=[f"{i}-{i+4}" for i in range(df_korea.index.year.min(), df_korea.index.year.max(), 5)])
df_world['Year5'] = pd.cut(df_world.index.year,
                          bins=range(df_world.index.year.min(), df_world.index.year.max() + 6, 5),
                          right=False,
                          labels=[f"{i}-{i+4}" for i in range(df_world.index.year.min(), df_world.index.year.max(), 5)])


df_world['Magnitude'] = df_world['Magnitude'].apply(lambda x: round(x,1))
df_korea = df_korea.rename(columns ={'도' : 'region'})

df_world.region = df_world.region.fillna('error')

# %%
df_world.index
# Out:
# DatetimeIndex(['1965-02-01 00:00:00+00:00', '1965-04-01 00:00:00+00:00',
#                '1965-05-01 00:00:00+00:00', '1965-08-01 00:00:00+00:00',
#                '1965-09-01 00:00:00+00:00', '1965-10-01 00:00:00+00:00',
#                '1965-12-01 00:00:00+00:00', '1965-01-15 00:00:00+00:00',
#                '1965-01-16 00:00:00+00:00', '1965-01-17 00:00:00+00:00',
#                ...
#                '2016-12-24 00:00:00+00:00', '2016-12-25 00:00:00+00:00',
#                '2016-12-25 00:00:00+00:00', '2016-12-27 00:00:00+00:00',
#                '2016-12-28 00:00:00+00:00', '2016-12-28 00:00:00+00:00',
#                '2016-12-28 00:00:00+00:00', '2016-12-28 00:00:00+00:00',
#                '2016-12-29 00:00:00+00:00', '2016-12-30 00:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='Date', length=23232, freq=None)

# %%
df_korea.index.year
# Out:
# Int64Index([1978, 1978, 1978, 1978, 1978, 1978, 1979, 1979, 1979, 1979,
#             ...
#             2024, 2024, 2024, 2024, 2024, 2024, 2024, 2024, 2024, 2024],
#            dtype='int64', name='발생시각', length=2248)

# %%
print(df_korea.info())
print(df_world.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2248 entries, 1978-08-30 02:29:43 to 2024-12-27 11:14:27
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Magnitude   2248 non-null   float64
#  1   Latitude    2248 non-null   float64
#  2   Longitude   2248 non-null   float64
#  3   지역          2248 non-null   object
#  4   남북          2248 non-null   object
#  5   region      2248 non-null   object
#  6   시군          2248 non-null   object
#  7   Month       2248 non-null   object
#  8   Year        2248 non-null   int64
#  9   Year_5년 단위  2248 non-null   object
#  10  Time        2248 non-null   datetime64[ns]
#  11  Year5       2248 non-null   category
# dtypes: category(1), datetime64[ns](1), float64(3), int64(1), object(6)
# memory usage: 213.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 23232 entries, 1965-02-01 00:00:00+00:00 to 2016-12-30 00:00:00+00:00
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Latitude   23232 non-null  float64
#  1   Longitude  23232 non-null  float64
#  2   Magnitude  23232 non-null  float64
#  3   Month      23232 non-null  object
#  4   Year       23232 non-null  int64
#  5   la_lo      23232 non-null  object
#  6   region     23165 non-null  object
#  7   Time       23232 non-null  datetime64[ns, UTC]
#  8   Year5      23232 non-null  category
# dtypes: category(1), datetime64[ns, UTC](1), float64(3), int64(1), object(3)
# memory usage: 1.6+ MB
# None

# %%
print(df_korea.index)
print(df_world.index)
# Out:
# DatetimeIndex(['1978-08-30 02:29:43', '1978-09-16 02:07:06',
#                '1978-10-07 18:19:52', '1978-11-23 11:06:05',
#                '1978-12-04 15:16:16', '1978-12-12 21:58:38',
#                '1979-01-01 00:11:22', '1979-01-24 00:40:57',
#                '1979-01-29 10:06:02', '1979-01-30 00:33:12',
#                ...
#                '2024-11-03 02:24:04', '2024-11-08 03:15:44',
#                '2024-11-14 23:33:00', '2024-12-03 08:53:39',
#                '2024-12-15 22:35:42', '2024-12-22 08:05:55',
#                '2024-12-25 21:16:45', '2024-12-27 09:43:10',
#                '2024-12-27 09:45:06', '2024-12-27 11:14:27'],
#               dtype='datetime64[ns]', name='발생시각', length=2248, freq=None)
# DatetimeIndex(['1965-02-01 00:00:00+00:00', '1965-04-01 00:00:00+00:00',
#                '1965-05-01 00:00:00+00:00', '1965-08-01 00:00:00+00:00',
#                '1965-09-01 00:00:00+00:00', '1965-10-01 00:00:00+00:00',
#                '1965-12-01 00:00:00+00:00', '1965-01-15 00:00:00+00:00',
#                '1965-01-16 00:00:00+00:00', '1965-01-17 00:00:00+00:00',
#                ...
#                '2016-12-24 00:00:00+00:00', '2016-12-25 00:00:00+00:00',
#                '2016-12-25 00:00:00+00:00', '2016-12-27 00:00:00+00:00',
#                '2016-12-28 00:00:00+00:00', '2016-12-28 00:00:00+00:00',
#                '2016-12-28 00:00:00+00:00', '2016-12-28 00:00:00+00:00',
#                '2016-12-29 00:00:00+00:00', '2016-12-30 00:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='Date', length=23232, freq=None)

# %%
df_korea.describe()
# Out:
#          Magnitude     Latitude    Longitude         Year
# count  2248.000000  2248.000000  2248.000000  2248.000000
# mean      2.601379    36.615538   127.553367  2009.980427
# std       0.530127     1.801995     1.707732    11.277444
# min       2.000000    32.350000   122.800000  1978.000000
# 25%       2.200000    35.750000   126.030000  2003.000000
# 50%       2.500000    36.200000   127.690000  2014.000000
# 75%       2.800000    37.672500   129.180000  2018.000000
# max       5.800000    41.600000   131.100000  2024.000000

# %%
df_world.describe()
# Out:
#            Latitude     Longitude     Magnitude          Year
# count  23232.000000  23232.000000  23232.000000  23232.000000
# mean       1.386383     39.746049      5.882765   1992.718018
# std       29.929060    125.751903      0.424037     14.438853
# min      -77.080000   -179.997000      5.500000   1965.000000
# 25%      -18.719500    -76.366500      5.600000   1981.000000
# 50%       -3.680000    106.349000      5.700000   1994.000000
# 75%       24.968500    145.290250      6.000000   2005.000000
# max       86.005000    179.998000      9.100000   2016.000000

# %% [markdown]
# # 시각화 차트 정리

# %% [markdown]
# ## distplot

# %%
import plotly.io as pio
pio.templates
# Out:
# Templates configuration
# -----------------------
#     Default template: 'vizro_dark'
#     Available templates:
#         ['ggplot2', 'seaborn', 'simple_white', 'plotly',
#          'plotly_white', 'plotly_dark', 'presentation', 'xgridoff',
#          'ygridoff', 'gridon', 'none', 'vizro_dark', 'vizro_light']

# %%
pio.templates.default = "plotly_white"

# %%
mag_min = df_korea['Magnitude'].min()
mag_min
# Out:
# 2.0

# %%
count_max = df_korea.groupby('Magnitude')['Time'].count().max()*1.1
mag_min = df_korea['Magnitude'].min()
mag_max = mag_min+0.1

lower_bound = mag_min
upper_bound = mag_max

# 구간 내 값들의 비율 계산
within_range = df_korea[(df_korea['Magnitude'] >= lower_bound) & (df_korea['Magnitude'] <= upper_bound)]
percentage = round((within_range.shape[0] / df_korea.shape[0]) * 100,1)


anno_text = f'Values ranging from {lower_bound} to {upper_bound}<br> account for {percentage}% of the total data'

fig = px.histogram(df_korea, x='Magnitude',  marginal='violin',
                   opacity=0.75, title='Distplot with Histogram and KDE',
                  )

fig.add_vrect(x0=mag_min, x1=mag_min+0.5,
            
              fillcolor="yellow", opacity=0.25, line_width=0)


fig.add_annotation(
        x=mag_min+0.5,
        y=count_max,
        xref="x",
        yref="y",
        text=anno_text,
        showarrow=True,
        font=dict(
            family="Courier New, monospace",
            size=16,
            color="#ffffff"
            ),
        align="center",
        arrowhead=2,
        arrowsize=1,
        arrowwidth=2,
        arrowcolor="#636363",
        ax=120,
        ay=-30,
        bordercolor="#c7c7c7",
        borderwidth=2,
        borderpad=4,
        bgcolor="#ff7f0e",
        opacity=0.8
        )
fig.update_xaxes(showspikes=True, spikecolor="green", spikesnap="cursor", spikemode="across")
fig.update_yaxes(showspikes=True, spikecolor="orange", spikethickness=2)
fig.update_layout(spikedistance=1000, hoverdistance=100)

fig.show()
# Out:
# <div>                            <div id="c9050884-0c7f-4bbe-906a-d854e4b8a9cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c9050884-0c7f-4bbe-906a-d854e4b8a9cd")) {                    Plotly.newPlot(                        "c9050884-0c7f-4bbe-906a-d854e4b8a9cd",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Magnitude=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","opacity":0.75,"pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[4.5,5.2,5.0,4.6,2.8,3.3,2.9,3.0,3.3,3.0,3.7,4.0,2.7,2.9,3.8,3.3,3.0,3.5,2.5,2.4,3.8,3.0,3.1,3.7,3.2,3.5,3.0,3.2,5.3,3.1,2.8,3.6,3.5,2.5,2.6,2.6,2.7,3.5,3.0,2.8,2.5,2.7,2.8,3.5,3.0,2.6,3.7,4.8,2.8,3.0,3.0,2.8,3.5,2.6,3.5,3.4,2.6,3.0,2.7,4.5,2.6,3.4,4.7,3.6,3.0,3.5,4.0,3.3,3.5,3.2,3.1,3.4,2.9,2.6,2.6,3.2,3.4,3.0,2.8,3.5,4.2,2.9,3.3,3.5,2.5,2.3,3.0,3.0,2.9,2.4,3.2,3.0,3.2,2.6,2.2,3.1,2.5,2.6,3.2,2.6,2.2,3.9,2.8,2.9,2.4,2.6,4.2,3.4,2.7,3.4,2.9,2.9,2.4,3.1,2.8,3.3,4.0,2.8,3.8,2.6,2.4,2.8,3.1,2.9,3.1,3.2,3.0,3.0,2.8,3.3,2.7,3.2,3.6,2.6,3.5,3.3,3.4,3.0,3.1,3.2,3.5,4.0,2.8,2.2,3.1,3.5,3.7,2.9,3.7,3.4,3.4,2.5,3.2,3.4,3.4,3.1,3.4,3.2,3.1,3.2,3.5,2.8,2.8,2.9,2.5,2.7,3.3,2.8,2.5,3.1,2.6,2.7,2.6,2.4,2.3,2.6,2.5,3.4,2.7,3.4,2.8,3.4,2.7,3.1,3.0,2.2,2.0,2.6,2.7,2.6,3.1,3.1,2.7,3.2,2.8,2.2,2.0,4.0,2.9,2.6,2.5,3.1,2.7,2.6,4.4,3.4,3.8,3.4,2.6,4.0,2.1,3.1,2.1,2.9,3.3,3.9,2.8,2.6,2.8,4.5,2.2,2.9,2.2,2.2,2.9,2.2,2.7,3.6,2.6,2.9,3.4,3.1,2.6,3.0,2.3,2.0,3.5,2.2,2.5,2.7,2.7,2.3,3.1,4.6,4.5,4.1,4.9,2.1,2.8,3.2,3.5,3.4,3.6,2.8,2.0,2.4,2.3,3.0,3.3,2.4,2.5,2.6,3.0,2.5,2.5,2.5,3.4,2.9,2.5,3.0,2.6,2.2,4.2,2.8,2.9,3.6,2.8,2.4,2.4,2.9,3.7,3.5,3.0,2.6,2.5,3.0,4.2,3.1,2.6,2.2,2.5,2.3,3.1,2.8,2.1,2.9,3.0,2.1,2.8,3.1,2.5,3.5,2.6,2.4,2.8,2.7,2.8,2.1,2.8,3.0,2.7,3.0,3.6,2.4,3.3,3.5,3.6,2.9,2.3,4.5,3.0,2.7,2.5,2.7,2.8,2.9,3.2,2.8,2.5,3.2,3.0,2.5,3.5,2.8,2.7,2.7,4.2,2.8,2.3,2.8,2.5,2.4,3.2,3.0,2.5,3.0,3.9,4.1,2.9,2.3,3.5,2.3,2.5,2.2,2.3,2.4,2.9,2.8,2.8,3.7,2.8,2.4,2.4,2.3,2.0,2.7,2.7,2.9,3.8,2.1,2.3,3.6,3.3,2.5,2.5,2.8,2.8,2.7,4.2,2.9,3.3,2.9,2.9,2.5,3.5,3.5,3.2,2.7,2.4,3.0,3.1,3.3,2.9,2.6,2.8,2.1,2.0,2.2,3.2,2.8,2.5,3.1,3.5,3.1,3.4,2.6,2.6,2.7,2.9,3.4,3.2,2.7,2.8,2.5,3.0,3.0,2.1,2.5,2.3,3.5,2.3,3.3,2.3,3.1,2.9,2.9,2.7,2.4,3.0,2.7,2.2,2.2,3.4,2.4,2.4,2.0,2.6,2.6,2.7,2.2,2.9,3.1,3.7,2.7,3.0,2.3,2.0,2.2,2.0,2.9,2.3,2.5,2.8,2.2,2.5,2.1,3.3,2.0,2.6,2.6,2.5,2.1,2.3,2.9,2.2,2.3,3.6,2.3,3.5,2.0,2.2,2.3,2.5,3.1,2.8,2.2,2.2,2.6,2.6,2.6,2.1,2.6,3.5,4.1,2.4,2.3,3.1,2.8,2.8,2.9,2.6,2.4,2.1,3.0,2.4,2.4,3.9,3.5,2.4,2.4,2.5,2.4,3.9,2.4,2.8,2.0,2.3,3.8,2.1,3.3,3.0,2.5,4.0,2.7,2.5,2.8,2.9,2.4,2.4,2.7,3.0,2.8,2.4,2.8,2.5,2.4,2.0,2.1,2.7,3.8,2.3,2.4,2.1,2.7,3.9,2.7,2.8,2.2,2.9,2.3,2.9,2.5,3.0,2.9,3.1,2.1,2.3,4.9,5.0,2.1,2.5,2.9,2.4,3.3,2.7,2.6,4.0,2.1,3.0,2.7,2.9,2.7,2.7,2.6,2.9,2.3,2.5,2.3,2.1,3.6,2.4,2.0,2.9,3.2,2.9,2.0,2.4,2.4,2.1,2.9,2.9,2.0,3.9,2.9,2.8,2.2,2.2,3.1,2.0,2.1,2.7,5.2,2.0,2.2,3.5,2.1,2.1,2.6,2.1,3.3,2.3,2.7,2.5,2.5,2.5,2.0,2.2,2.7,2.7,2.0,2.4,2.5,2.3,2.1,2.4,2.5,2.8,3.4,2.4,3.1,2.2,2.4,2.4,2.4,3.0,3.6,2.6,2.5,2.3,2.5,3.9,3.0,3.0,4.0,3.1,3.1,3.4,2.4,2.2,2.1,2.1,3.5,2.7,3.2,2.7,2.2,3.1,3.1,2.5,2.2,2.6,3.2,2.0,2.1,3.0,2.3,2.3,2.5,2.1,2.4,2.9,2.0,2.5,2.4,2.0,3.3,2.8,2.4,3.0,2.5,2.4,2.1,3.0,2.5,2.5,3.5,2.5,2.4,2.4,2.0,2.0,2.5,2.0,2.0,2.8,2.3,2.2,2.6,2.1,3.4,2.2,2.4,2.2,2.6,2.4,2.9,2.4,2.7,2.5,2.1,2.2,2.4,2.0,4.8,2.4,2.2,2.0,2.9,2.8,2.3,2.0,2.2,2.1,2.1,2.2,2.5,2.4,2.5,2.1,2.2,2.2,2.2,2.6,2.1,2.4,2.1,2.5,2.9,2.7,3.0,2.6,2.2,2.9,2.5,2.2,2.1,2.9,2.1,2.5,2.1,2.2,2.6,2.7,3.2,2.2,2.2,3.9,2.3,2.2,2.6,2.5,2.4,3.2,2.0,2.2,2.0,2.7,2.8,2.6,4.2,2.2,2.3,2.3,2.1,2.5,2.5,3.2,2.4,2.2,2.2,3.0,2.6,2.4,2.5,2.8,2.1,3.4,2.3,3.0,3.0,2.5,2.4,2.3,2.4,2.7,2.3,3.5,2.2,2.2,2.1,2.5,2.2,2.1,3.2,3.0 ...

# %%
@capture("graph")
def get_distplot(data_frame, w=800,h=600):
    count_max = data_frame.groupby('Magnitude')['Time'].count().max()*1.1
    mag_min = data_frame['Magnitude'].min()
    mag_max = mag_min+0.1

    lower_bound = mag_min
    upper_bound = mag_max

    # 구간 내 값들의 비율 계산
    within_range = data_frame[(data_frame['Magnitude'] >= lower_bound) & (data_frame['Magnitude'] <= upper_bound)]
    percentage = round((within_range.shape[0] / data_frame.shape[0]) * 100,1)


    anno_text = f'Values ranging from {lower_bound} to {upper_bound}<br> account for {percentage}% of the total data'

    fig = px.histogram(data_frame, x='Magnitude',  marginal='violin',
                       opacity=0.75, title='Distplot with Histogram and KDE',
                      )

    fig.add_vrect(x0=mag_min, x1=mag_min+0.5,
                  #annotation_text=anno_text, annotation_position="top right",
                  fillcolor="yellow", opacity=0.25, line_width=0)

    fig.add_annotation(
            x=mag_min+0.5,
            y=count_max,
            xref="x",
            yref="y",
            text=anno_text,
            showarrow=True,
            font=dict(
                family="Courier New, monospace",
                size=16,
                color="#ffffff"
                ),
            align="center",
            arrowhead=2,
            arrowsize=1,
            arrowwidth=2,
            arrowcolor="#636363",
            ax=120,
            ay=-30,
            bordercolor="#c7c7c7",
            borderwidth=2,
            borderpad=4,
            bgcolor="#ff7f0e",
            opacity=0.8
            )    
    
    fig.update_xaxes(showspikes=True, spikecolor="green", spikesnap="cursor", spikemode="across")
    fig.update_yaxes(showspikes=True, spikecolor="orange", spikethickness=2)
    fig.update_layout(spikedistance=1000, hoverdistance=100)    
    return fig

# %% [markdown]
# ## 월별 통계 - simple

# %%
#기존에는 이렇게 만들엇는데,
# 이렇게 하면 vizro에서 순서가 원상복구됨.
fig = px.histogram(df_korea, x="Month")
fig.update_xaxes(categoryorder='array', categoryarray= ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
fig.update_layout(width=800, height=600)
fig.show()
# Out:
# <div>                            <div id="7cd4aef4-01fa-4fe7-bcf9-a836c60bc6a2" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7cd4aef4-01fa-4fe7-bcf9-a836c60bc6a2")) {                    Plotly.newPlot(                        "7cd4aef4-01fa-4fe7-bcf9-a836c60bc6a2",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Month=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["August","September","October","November","December","December","January","January","January","January","February","February","February","February","March","April","April","August","August","August","August","August","October","October","November","December","December","December","January","May","June","June","July","August","September","November","November","December","December","December","December","December","December","January","March","April","April","April","May","May","June","June","August","September","September","September","October","December","February","February","February","February","March","March","March","May","August","August","August","August","October","January","February","February","February","May","June","June","August","August","September","September","October","October","December","December","December","January","January","January","February","March","March","March","April","April","May","May","May","May","June","July","August","October","November","November","January","January","March","April","May","May","May","June","June","June","June","June","June","June","July","August","August","November","November","December","December","January","February","February","March","March","March","March","April","April","May","May","May","July","August","March","June","September","October","October","October","January","April","May","October","December","January","March","March","March","April","May","May","June","June","December","December","January","January","January","February","February","February","February","March","March","March","June","June","June","June","October","January","January","January","February","March","April","April","May","May","May","June","June","July","July","August","October","October","October","January","January","April","May","July","July","September","October","November","November","November","November","November","December","December","January","February","February","March","March","March","March","March","March","April","April","April","April","May","June","June","July","July","August","December","December","December","January","January","February","February","February","February","March","March","March","April","April","April","April","July","August","August","September","October","November","December","December","December","December","December","January","January","January","February","February","March","March","April","April","May","May","June","June","June","June","July","August","August","August","August","September","September","October","October","October","November","December","December","December","January","February","February","March","March","April","April","April","May","May","May","May","May","May","May","May","June","June","June","June","June","June","July","July","August","August","September","September","October","November","November","November","November","December","December","December","December","December","December","January","January","March","April","May","May","May","May","June","June","June","June","June","August","August","September","October","October","October","November","November","January","February","February","April","April","April","May","May","May","May","June" ...

# %%
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

df_korea['Month'] = pd.Categorical(df_korea['Month'], month_order)
df_world['Month'] = pd.Categorical(df_world['Month'], month_order)

df_korea_sort_month = df_korea.sort_values('Month')
df_world_sort_month = df_world.sort_values('Month')

# %%
fig = px.histogram(df_korea_sort_month, x="Month")
fig.update_layout(width=800, height=600)
fig.show()
# Out:
# <div>                            <div id="c23d43b1-3d80-43df-9374-695cf0e680b7" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c23d43b1-3d80-43df-9374-695cf0e680b7")) {                    Plotly.newPlot(                        "c23d43b1-3d80-43df-9374-695cf0e680b7",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Month=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","January","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","February","Febr ...

# %%
def get_month_chart_simple(df,w=800,h=600):
    fig = px.histogram(df, x="Month")
    fig.update_layout(width=w, height=h)
    return fig

# %% [markdown]
# ## 월별 통계-stack

# %%
fig = px.histogram(df_world, x="Month", color="Year",
                   category_orders={"Month": ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']},
                   barmode='stack',
                  )

fig.update_layout(width=800, height=600)
fig.show()
# Out:
# <div>                            <div id="ee6fc58b-6b0c-468a-bbe4-ce213fbc874a" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee6fc58b-6b0c-468a-bbe4-ce213fbc874a")) {                    Plotly.newPlot(                        "ee6fc58b-6b0c-468a-bbe4-ce213fbc874a",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Year=1965\u003cbr\u003eMonth=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1965","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1965","offsetgroup":"1965","orientation":"v","showlegend":true,"x":["February","April","May","August","September","October","December","January","January","January","January","January","January","January","February","April","April","April","April","April","April","April","April","April","April","April","April","April","April","April","April","April","April","April","May","May","May","May","May","June","June","June","June","June","June","June","July","July","July","August","September","September","December","February","February","February","February","February","February","February","February","February","February","February","February","February","February","January","January","January","January","January","January","February","March","March","March","April","May","May","May","May","June","June","July","September","March","March","March","March","March","March","March","March","March","March","March","March","March","March","March","March","March","March","March","January","March","April","April","May","May","June","June","August","September","September","October","October","October","November","November","December","April","April","April","April","April","April","April","April","April","April","April","April","April","April","April","April","January","February","March","March","March","April","December","December","May","May","May","May","May","May","May","May","May","May","May","May","May","May","February","February","May","November","November","November","November","November","November","December","December","December","December","December","June","June","June","June","June","June","June","June","June","June","June","June","June","June","June","June","June","June","January","February","March","June","June","June","June","July","December","July","July","July","July","July","July","July","July","July","July","July","July","January","February","March","May","November","November","November","November","November","December","December","December","August","August","August","August","August","August","August","August","August","August","August","August","August","August","August","August","August","August","August","August","August","August","January","February","April","April","August","September","November","December","December","September","September","September","September","September","September","September","September","September","September","September","September","September","September","September","September","September","September","September","January","January","January","March","March","July","October","December","October","October","October","October","October","October","October","October","October","March","March","May","June","December","November","November","November","November","November","November","November","November","November","November","November","November","November","November","November","November","November","November","November","November","November","November","April","May","June","July","August","September","September","October","December","December","December","December","December","December","December","December","December","December","December","December"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","h ...

# %%
def get_month_chart_stack(df,w=800,h=600):
    fig = px.histogram(df, x="Month", color="Year",
                       category_orders={"Month": ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']},
                       barmode='stack',
                      )

    fig.update_layout(width=w, height=h)
    return fig

# %% [markdown]
# ## 월별 통계 stack 5년

# %%
fig = px.histogram(df_korea, x="Month", color="Year5",
                   category_orders={"Month": ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']},
                   barmode='stack',
                  )

fig.update_layout(width=800, height=600)


fig.show()
# Out:
# <div>                            <div id="7f4c945c-561e-4d55-8a57-3c8bd6926045" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f4c945c-561e-4d55-8a57-3c8bd6926045")) {                    Plotly.newPlot(                        "7f4c945c-561e-4d55-8a57-3c8bd6926045",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Year5=1978-1982\u003cbr\u003eMonth=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1978-1982","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1978-1982","offsetgroup":"1978-1982","orientation":"v","showlegend":true,"x":["August","September","October","November","December","December","January","January","January","January","February","February","February","February","March","April","April","August","August","August","August","August","October","October","November","December","December","December","January","May","June","June","July","August","September","November","November","December","December","December","December","December","December","January","March","April","April","April","May","May","June","June","August","September","September","September","October","December","February","February","February","February","March","March","March","May","August","August","August","August","October"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Year5=1983-1987\u003cbr\u003eMonth=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1983-1987","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"1983-1987","offsetgroup":"1983-1987","orientation":"v","showlegend":true,"x":["January","February","February","February","May","June","June","August","August","September","September","October","October","December","December","December","January","January","January","February","March","March","March","April","April","May","May","May","May","June","July","August","October","November","November","January","January","March","April","May","May","May","June","June","June","June","June","June","June","July","August","August","November","November","December","December","January","February","February","March","March","March","March","April","April","May","May","May","July","August","March","June","September","October","October","October"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Year5=1988-1992\u003cbr\u003eMonth=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1988-1992","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"1988-1992","offsetgroup":"1988-1992","orientation":"v","showlegend":true,"x":["January","April","May","October","December","January","March","March","March","April","May","May","June","June","December","December","January","January","January","February","February","February","February","March","March","March","June","June","June","June","October","January","January","January","February","March","April","April","May","May","May","June","June","July","July","August","October","October","October","January","January","April","May","July","July","September","October","November","November","November","November","November","December","December"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Year5=1993-1997\u003cbr\u003eMonth=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1993-1997","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"1993-1997","offsetgroup":"1993-1997","orientation":"v","showlegend":true,"x":["January","February","February","March","March","March","March","March","March","April","April","April","April","May"," ...

# %%
def get_month_chart_stack5(df, w=800,h=600):

    fig = px.histogram(df, x="Month", color="Year5",
                       category_orders={"Month": ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']},
                       barmode='stack',
                      )

    fig.update_layout(width=w, height=h)


    return fig

# %% [markdown]
# ## 연도별 차트 - Trendline

# %%
yearly_groups = df_world.groupby(df_world.index.year)
data = yearly_groups[['Magnitude']].count()
fig = px.scatter(data_frame=data, trendline='ols')
fig.update_layout(width=800, height=600)
fig.show()
# Out:
# <div>                            <div id="44509fdc-49ad-4ee2-afae-5882f4ecc497" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44509fdc-49ad-4ee2-afae-5882f4ecc497")) {                    Plotly.newPlot(                        "44509fdc-49ad-4ee2-afae-5882f4ecc497",                        [{"hovertemplate":"variable=Magnitude\u003cbr\u003eDate=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Magnitude","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Magnitude","orientation":"v","showlegend":true,"x":[1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016],"xaxis":"x","y":[339,233,255,303,322,344,386,388,394,355,402,447,417,395,343,335,313,340,443,467,469,484,489,479,473,524,428,532,465,506,589,540,456,388,446,553,443,444,485,571,533,508,608,508,517,559,713,445,461,480,446,469],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003evalue = 4.3993 * Date + -8310.04\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.524260\u003cbr\u003e\u003cbr\u003evariable=Magnitude\u003cbr\u003eDate=%{x}\u003cbr\u003evalue=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Magnitude","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"Magnitude","showlegend":false,"x":[1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016],"xaxis":"x","y":[334.5870827285944,338.9863826517576,343.385682574919,347.7849824980822,352.18428242124355,356.58358234440675,360.98288226756813,365.3821821907313,369.7814821138927,374.1807820370559,378.5800819602173,382.9793818833805,387.37868180654186,391.77798172970506,396.17728165286644,400.57658157602964,404.97588149919284,409.3751814223542,413.7744813455174,418.1737812686788,422.573081191842,426.9723811150034,431.37168103816657,435.77098096132795,440.17028088449115,444.5695808076525,448.9688807308157,453.3681806539771,457.7674805771403,462.1667805003017,466.5660804234649,470.96538034662626,475.36468026978946,479.76398019295084,484.16328011611404,488.5625800392754,492.9618799624386,497.3611798856,501.7604798087632,506.1597797319246,510.55907965508777,514.9583795782492,519.3576795014123,523.7569794245737,528.1562793477369,532.5555792708983,536.9548791940615,541.3541791172229,545.7534790403861,550.1527789635493,554.5520788867107,558.9513788098739],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth": ...

# %%
yearly_groups = df_korea.groupby(df_korea.index.year)
data = yearly_groups[['Magnitude']].count()
fig = px.scatter(data_frame=data,trendline=None)
fig.update_layout(width=800, height=600)
fig.show()
# Out:
# <div>                            <div id="5dff1352-e724-447b-b44c-580100bb2d99" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5dff1352-e724-447b-b44c-580100bb2d99")) {                    Plotly.newPlot(                        "5dff1352-e724-447b-b44c-580100bb2d99",                        [{"hovertemplate":"variable=Magnitude\u003cbr\u003e\ubc1c\uc0dd\uc2dc\uac01=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Magnitude","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Magnitude","orientation":"v","showlegend":true,"x":[1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024],"xaxis":"x","y":[6,22,15,15,13,16,19,21,14,6,5,11,15,18,15,22,24,29,39,21,32,37,29,41,49,38,42,37,50,42,46,60,42,52,56,93,49,44,252,223,115,88,68,70,77,106,64],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"c ...

# %%
def get_year_chart(df,w=800,h=600):
    yearly_groups = df.groupby(df.index.year)
    data = yearly_groups[['Magnitude']].count()
    fig = px.scatter(data_frame=data)
    fig.update_layout(width=w, height=h)
    return fig

# %% [markdown]
# ## 연도별차트 - Range

# %%
dk_mag_range = [df_korea['Magnitude'].describe()['25%'],df_korea['Magnitude'].describe()['50%']
                ,df_korea['Magnitude'].describe()['75%'],df_korea['Magnitude'].describe()['max']]
dw_mag_range = [df_world['Magnitude'].describe()['25%'],df_world['Magnitude'].describe()['50%']
                ,df_world['Magnitude'].describe()['75%'],df_world['Magnitude'].describe()['max']]

# %%
k_magnitude_order=[str(r)+'미만' for r in dk_mag_range]

df_korea['Magnitude Range 5 Year'] = pd.cut(df_korea['Magnitude'], bins=[-float('inf')] + dk_mag_range, right=False, 
                               labels=k_magnitude_order)
fig = px.histogram(df_korea, x='Year', color="Magnitude Range 5 Year",
                                      category_orders={'Magnitude Range 5 Year': k_magnitude_order},
                   #nbins = len(df['Year'].value_counts().index)   #이거 빼면 2년씩 묶임
                  )
fig.show()
# Out:
# <div>                            <div id="a1f946a1-2c07-4e13-8d7f-0fa270f60124" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1f946a1-2c07-4e13-8d7f-0fa270f60124")) {                    Plotly.newPlot(                        "a1f946a1-2c07-4e13-8d7f-0fa270f60124",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Magnitude Range 5 Year=2.2\ubbf8\ub9cc\u003cbr\u003eYear=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2.2\ubbf8\ub9cc","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"2.2\ubbf8\ub9cc","offsetgroup":"2.2\ubbf8\ub9cc","orientation":"v","showlegend":true,"x":[1991,1992,1992,1993,1994,1994,1994,1996,1996,1996,1998,1998,1999,1999,2000,2000,2001,2001,2001,2001,2001,2001,2001,2002,2002,2002,2002,2002,2002,2003,2003,2003,2003,2003,2004,2004,2004,2004,2004,2004,2004,2004,2004,2004,2004,2004,2005,2005,2006,2006,2006,2006,2006,2006,2006,2006,2006,2006,2006,2006,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2008,2008,2008,2008,2009,2009,2009,2010,2010,2010,2010,2010,2011,2011,2011,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2014,2014,2014,2014,2014,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2019,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2020,2021,2021,2021,2021,2021,2021,2021,2021,2021,2021,2021,2021,2021,2021,2021,2021,2021,2021,2021,2021,2022,2022,2022,2022,2022,2022,2022,2022,2022,2022,2022,2022,2022,2022,2022,2022,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2023,2024,2024,2024,2024,2024,2024,2024,2024,2024,2024,2024,2024,2024,2024,2024,2024],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Magnitude Range 5 Year=2.5\ubbf8\ub9cc\u003cbr\u003eYear=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"2.5\ubbf8\ub9cc","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"2.5\ubbf8\ub9cc","offsetgroup":"2.5\ubbf8\ub9cc","orientation":"v","showlegend":true,"x":[1979,1983,1984,1984,1984,1984,1985,1985,1987,1990,1990,1991,1991,1993,1993,1993,1993,1994,1994,1994,1994,1994,1995,1995,1995,1995,1996,1996,1996,1996,1996,1997,1997,1998,1998,1998,1998,1998,1998,1998,1998,1998,1999,1999,2000,2000,2000,2000,2000,2000,2000,2000,2000,2001,2001,2001,2001,2001,2001,2001,2001,2001,2001,2001,2001,2001,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2003,2003,2003,2003,2003,2003,2003,2004,2004,2004,2004,2004,2004,2004,2004,2004,2005,2005,2005,2005,2005,2005,2005,2005,2005,2005,2005,2006,2006,2006,2006,2006,2006,2006,2006,2006,2006,20 ...

# %%
df_world[df_world['Year'].isin([2015,2016])]
# Out:
#                            Latitude  Longitude  Magnitude     Month  Year  \
# Date
# 2015-02-01 00:00:00+00:00    6.5739    60.3653        5.5  February  2015
# 2015-05-01 00:00:00+00:00  -43.0546   171.2364        5.6       May  2015
# 2015-06-01 00:00:00+00:00   55.2049   163.2446        5.6      June  2015
# 2015-07-01 00:00:00+00:00    5.9045   -82.6576        6.5      July  2015
# 2015-08-01 00:00:00+00:00  -61.6118   161.3346        5.7    August  2015
# ...                             ...        ...        ...       ...   ...
# 2016-12-28 00:00:00+00:00   38.3917  -118.8941        5.6  December  2016
# 2016-12-28 00:00:00+00:00   38.3777  -118.8957        5.5  December  2016
# 2016-12-28 00:00:00+00:00   36.9179   140.4262        5.9  December  2016
# 2016-12-29 00:00:00+00:00   -9.0283   118.6639        6.3  December  2016
# 2016-12-30 00:00:00+00:00   37.3973   141.4103        5.5  December  2016
#
#                                           la_lo                 region  \
# Date
# 2015-02-01 00:00:00+00:00     [6.5739, 60.3653]                  error
# 2015-05-01 00:00:00+00:00  [-43.0546, 171.2364]            New Zealand
# 2015-06-01 00:00:00+00:00   [55.2049, 163.2446]                  error
# 2015-07-01 00:00:00+00:00    [5.9045, -82.6576]                  error
# 2015-08-01 00:00:00+00:00  [-61.6118, 161.3346]                  error
# ...                                         ...                    ...
# 2016-12-28 00:00:00+00:00  [38.3917, -118.8941]          United States
# 2016-12-28 00:00:00+00:00  [38.3777, -118.8957]          United States
# 2016-12-28 00:00:00+00:00   [36.9179, 140.4262]                  Japan
# 2016-12-29 00:00:00+00:00   [-9.0283, 118.6639]                  error
# 2016-12-30 00:00:00+00:00   [37.3973, 141.4103]  Japan Full Region Sea
#
#                                                Time      Year5
# Date
# 2015-02-01 00:00:00+00:00 2015-02-01 00:00:00+00:00  2015-2019
# 2015-05-01 00:00:00+00:00 2015-05-01 00:00:00+00:00  2015-2019
# 2015-06-01 00:00:00+00:00 2015-06-01 00:00:00+00:00  2015-2019
# 2015-07-01 00:00:00+00:00 2015-07-01 00:00:00+00:00  2015-2019
# 2015-08-01 00:00:00+00:00 2015-08-01 00:00:00+00:00  2015-2019
# ...                                             ...        ...
# 2016-12-28 00:00:00+00:00 2016-12-28 00:00:00+00:00  2015-2019
# 2016-12-28 00:00:00+00:00 2016-12-28 00:00:00+00:00  2015-2019
# 2016-12-28 00:00:00+00:00 2016-12-28 00:00:00+00:00  2015-2019
# 2016-12-29 00:00:00+00:00 2016-12-29 00:00:00+00:00  2015-2019
# 2016-12-30 00:00:00+00:00 2016-12-30 00:00:00+00:00  2015-2019
#
# [915 rows x 9 columns]

# %%
w_magnitude_order=[str(r)+'미만' for r in dw_mag_range]

df_world['Magnitude Range 5 Year'] = pd.cut(df_world['Magnitude'], bins=[-float('inf')] + dw_mag_range, right=False, 
                               labels=w_magnitude_order)

fig = px.histogram(df_world, x='Year', color="Magnitude Range 5 Year",
                   category_orders={'Magnitude Range 5 Year': w_magnitude_order},
                  )
fig.show()
# Out:
# <div>                            <div id="d7545d82-8597-414c-811d-b49ac385e6a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d7545d82-8597-414c-811d-b49ac385e6a7")) {                    Plotly.newPlot(                        "d7545d82-8597-414c-811d-b49ac385e6a7",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Magnitude Range 5 Year=5.6\ubbf8\ub9cc\u003cbr\u003eYear=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"5.6\ubbf8\ub9cc","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"5.6\ubbf8\ub9cc","offsetgroup":"5.6\ubbf8\ub9cc","orientation":"v","showlegend":true,"x":[1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1966,1966,1966,1967,1967,1967,1967,1968,1968,1968,1968,1969,1969,1969,1969,1969,1969,1969,1969,1969,1970,1970,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1971,1972,1972,1972,1972,1972,1972,1972,1972,1972,1972,1972,1972,1972,1972,1972,1972,1972,1972,1972,1972,1972,1972,1972,1972,1972,1972,1972,1972,1972,1972,1972,1972,1972,1972,1972,1972,1972,1972,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1973,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1974,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1975,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1976,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,1977,197 ...

# %%
def get_mag_range(df, magnitude_order):


    fig = px.histogram(df, x='Year', color="Magnitude Range 5 Year",
                       category_orders={'Magnitude Range 5 Year': magnitude_order},
                      )
    return fig

# %% [markdown]
# # vizro 시작

# %%
date_strings = ['January 1, 2016', 'December 31, 2018']
date_format = '%B %d, %Y'
k_datetime_objects = [datetime.strptime(date_str, date_format) for date_str in date_strings]

k_datetime_objects
# Out:
# [datetime.datetime(2016, 1, 1, 0, 0), datetime.datetime(2018, 12, 31, 0, 0)]

# %%
date(2016,1,1)
# Out:
# datetime.date(2016, 1, 1)

# %%
df_world
# Out:
#                            Latitude  Longitude  Magnitude      Month  Year  \
# Date
# 1965-02-01 00:00:00+00:00   19.2460   145.6160        6.0   February  1965
# 1965-04-01 00:00:00+00:00    1.8630   127.3520        5.8      April  1965
# 1965-05-01 00:00:00+00:00  -20.5790  -173.9720        6.2        May  1965
# 1965-08-01 00:00:00+00:00  -59.0760   -23.5570        5.8     August  1965
# 1965-09-01 00:00:00+00:00   11.9380   126.4270        5.8  September  1965
# ...                             ...        ...        ...        ...   ...
# 2016-12-28 00:00:00+00:00   38.3917  -118.8941        5.6   December  2016
# 2016-12-28 00:00:00+00:00   38.3777  -118.8957        5.5   December  2016
# 2016-12-28 00:00:00+00:00   36.9179   140.4262        5.9   December  2016
# 2016-12-29 00:00:00+00:00   -9.0283   118.6639        6.3   December  2016
# 2016-12-30 00:00:00+00:00   37.3973   141.4103        5.5   December  2016
#
#                                           la_lo                 region  \
# Date
# 1965-02-01 00:00:00+00:00     [19.246, 145.616]         Philippine Sea
# 1965-04-01 00:00:00+00:00      [1.863, 127.352]            Molucca Sea
# 1965-05-01 00:00:00+00:00   [-20.579, -173.972]                  error
# 1965-08-01 00:00:00+00:00    [-59.076, -23.557]         Southern Ocean
# 1965-09-01 00:00:00+00:00     [11.938, 126.427]         Philippine Sea
# ...                                         ...                    ...
# 2016-12-28 00:00:00+00:00  [38.3917, -118.8941]          United States
# 2016-12-28 00:00:00+00:00  [38.3777, -118.8957]          United States
# 2016-12-28 00:00:00+00:00   [36.9179, 140.4262]                  Japan
# 2016-12-29 00:00:00+00:00   [-9.0283, 118.6639]                  error
# 2016-12-30 00:00:00+00:00   [37.3973, 141.4103]  Japan Full Region Sea
#
#                                                Time      Year5  \
# Date
# 1965-02-01 00:00:00+00:00 1965-02-01 00:00:00+00:00  1965-1969
# 1965-04-01 00:00:00+00:00 1965-04-01 00:00:00+00:00  1965-1969
# 1965-05-01 00:00:00+00:00 1965-05-01 00:00:00+00:00  1965-1969
# 1965-08-01 00:00:00+00:00 1965-08-01 00:00:00+00:00  1965-1969
# 1965-09-01 00:00:00+00:00 1965-09-01 00:00:00+00:00  1965-1969
# ...                                             ...        ...
# 2016-12-28 00:00:00+00:00 2016-12-28 00:00:00+00:00  2015-2019
# 2016-12-28 00:00:00+00:00 2016-12-28 00:00:00+00:00  2015-2019
# 2016-12-28 00:00:00+00:00 2016-12-28 00:00:00+00:00  2015-2019
# 2016-12-29 00:00:00+00:00 2016-12-29 00:00:00+00:00  2015-2019
# 2016-12-30 00:00:00+00:00 2016-12-30 00:00:00+00:00  2015-2019
#
#                           Magnitude Range 5 Year
# Date
# 1965-02-01 00:00:00+00:00                  9.1미만
# 1965-04-01 00:00:00+00:00                  6.0미만
# 1965-05-01 00:00:00+00:00                  9.1미만
# 1965-08-01 00:00:00+00:00                  6.0미만
# 1965-09-01 00:00:00+00:00                  6.0미만
# ...                                          ...
# 2016-12-28 00:00:00+00:00                  5.7미만
# 2016-12-28 00:00:00+00:00                  5.6미만
# 2016-12-28 00:00:00+00:00                  6.0미만
# 2016-12-29 00:00:00+00:00                  9.1미만
# 2016-12-30 00:00:00+00:00                  5.6미만
#
# [23232 rows x 10 columns]

# %%
df_world.groupby('region')['region'].count().sort_values()
# Out:
# region
# İzmit Bay                               1
# Heard Island and McDonald Islands       1
# Suō Gulf                                1
# Gulf of Tonkin                          1
# Gulf of Panama                          1
#                                      ...
# Chile                                 594
# Philippine Sea                        962
# Japan Full Region Sea                1094
# Papua New Guinea                     1185
# error                                9122
# Name: region, Length: 225, dtype: int64

# %%
Vizro._reset()


dist_k = get_distplot(df_korea)
dist_k_filter = get_distplot(df_korea)
month_k = get_month_chart_simple(df_korea_sort_month)
year_k = get_year_chart(df_korea)
year_5_k = get_mag_range(df_korea, k_magnitude_order)
month_stack_k = get_month_chart_stack(df_korea)
month_stack5_k = get_month_chart_stack5(df_korea)



dist_w = get_distplot(df_world)
dist_w_filter = get_distplot(df_world)
month_w = get_month_chart_simple(df_world_sort_month)
year_w = get_year_chart(df_world)
year_5_w = get_mag_range(df_world, w_magnitude_order)
month_stack_w = get_month_chart_stack(df_world)
month_stack5_w = get_month_chart_stack5(df_world)





page_Korea_Magnitude = vm.Page(
    id = "Korea Magnitude",
    title="Magnitude2",
    layout=vm.Layout(grid=[[0, 1],
                           [0, 1],
                            [2, 3]]),      
    components=[
        vm.Graph(id="dist_korea", figure=dist_k),
        vm.Graph(id="dist_korea_filter", figure=dist_k_filter),
        vm.Card(
            text="""
                # 한국 지진 규모 분석&nbsp;
                * 1978년부터 현재까지 남북한 전체의 지진발생을 기록한 데이터입니다.
                * 대부분의 지진은 규모 3.5미만입니다.&nbsp;
                * 규모 2.0~2.1 구간에서 전체 지진의 18.7%가 발생합니다.
                * 가장 규모가 큰 지진도 규모6이 되지 않습니다.
            """,
        ),            
        vm.Card(
            text="""
                ### 지역,날짜로 필터링한 한국 지진 규모 분석&nbsp;
                * 기본값은 2016년1월1일 - 2018년12월31일 까지 경남,경북에서 발생한 지진을 필터링 한 것입니다.
                * 이 좁은 지역, 짧은 기간 동안 한반도 전체 지진의 1/4가 발생했습니다. 
                * 다른 지역도 살펴보고 싶다면 왼쪽 filter를 조정해주세요
            """,
        ),                    
    ],
    controls=[
        vm.Filter(column="Time", targets = ['dist_korea_filter'],selector=vm.DatePicker(value=[date(2016,1,1), date(2018,12,31)])),
        vm.Filter(column="region", targets = ['dist_korea_filter'], selector=vm.Dropdown(value=['경북','경남'])),
    
    ], 
)

page_Korea_Month = vm.Page(
    id="Korea Month",
    title="Month",
    components=[
        vm.Graph(id="month_korea", figure=month_k),
        vm.Graph(id="month_stack_korea", figure=month_stack_k),
        vm.Graph(id="month_stack5_korea", figure=month_stack5_k),        
    ]
)

page_Korea_Year = vm.Page(
    id ="Korea Year",
    title="Year",
    layout=vm.Layout(grid=[[0, 0, 2],
                           [1, 1, 2],
                            [1, 1, 2]]),     
    components=[
        vm.Graph(id="year_korea", figure=year_k),
        vm.Graph(id="year_5_korea", figure=year_5_k),
        vm.Card(
            text="""
                ### Card Title
                Commodi repudiandae consequuntur voluptatum.
            """,
        ),
    ],
    controls=[
        vm.Parameter(
                      targets=["year_korea.trendline"],
                     selector=vm.Dropdown(
                      options=['lowess', 'expanding', 'ols'],
                multi=False,
                value="ols",
                     )),
    
    ]    
)

page_World_Magnitude = vm.Page(
    id="World Magnitude",
    title="Magnitude",
    layout=vm.Layout(grid=[[0, 1],
                           [0, 1],
                            [2, 3]]),      
    components=[
        vm.Graph(id="dist_world", figure=dist_w),
        vm.Graph(id="dist_world_filter", figure=dist_w_filter),
        vm.Card(
            text="""
    ```html
    <script src="https://unpkg.com/typed.js@2.1.0/dist/typed.umd.js"></script>
    <script>
        var typed = new Typed('#typed-text', {
            strings: ['This is a Typed.js example.', 'You can add typewriter effect using Typed.js in Dash.'],
            typeSpeed: 50,
            loop: true
        });
    </script>
    ```            
                # 외국 지진 규모 분석&nbsp;
                * 1965년부터 현재까지 세계각지의 지진발생을 기록한 데이터입니다.
                * 5.5미만의 여진은 기록되지 않은 데이터입니다.
                * 대부분의 지진은 규모 6미만입니다.&nbsp;
                * 규모 5.5~5.6 구간에서 전체 지진의 37.1%가 발생합니다.
            """,
        ),            
        vm.Card(
            text="""
                ### 지역,날짜로 필터링한 세계 지진 규모 분석&nbsp;
                * 기본값은 2016년1월1일 - 2018년12월31일 까지 일본에서 발생한 지진을 필터링 한 것입니다.
                
                * 다른 지역도 살펴보고 싶다면 왼쪽 filter를 조정해주세요
            """,
        ),                    
    ],
    controls=[
        vm.Filter(column="Time", targets = ['dist_world_filter'],selector=vm.DatePicker(value=[date(2016,1,1), date(2018,12,31)])),
        vm.Filter(column="region", targets = ['dist_world_filter'], selector=vm.Dropdown(value=['Japan'])),
    
    ],     
)

page_World_Month = vm.Page(
    id="World Month",
    title="Month",
    layout=vm.Layout(grid=[[0, 0, 2],
                           [1, 1, 2],
                            [1, 1, 2]]),    
    components=[
        vm.Graph(id="month_world", figure=month_w),
        vm.Graph(id="month_stack_world", figure=month_stack_w),
        vm.Graph(id="month_stack5_world", figure=month_stack5_w),
    ],
 
)

page_World_Year = vm.Page(
    id="World Year",
    title="Year",
    layout=vm.Layout(grid=[[0, 0, 2],
                           [1, 1, 2],
                            [1, 1, 2]]),       
    components=[
        vm.Graph(id="year_world", figure=year_w),
        vm.Graph(id="year_5_world", figure=year_5_w),
        vm.Card(
            text="""
                # 데이터 분석
                
                ## 연간 지진 발생 횟수\n\n\n
                
                ### 지진 발생 횟수 자체가 늘어나고 있는 것인가?
                아님. 지진 관측 능력이 향상되어 많이 관측 되는 것.
                ### 지진 발생 횟수가 계단식이 아닌 점진적 증가를 나타내는 이유?
                
                지진관측 능력은 관측 기기의 성능보다(계단식 증가)
                지진 관측소의 개수에 영향을 많이 받기 때문(점진적 증가)
                
                # 
            """,
        ),        
    ],
    controls=[
        vm.Parameter(
                      targets=["year_world.trendline"],
                     selector=vm.Dropdown(
                      options=['lowess', 'expanding', 'ols'],
                multi=False,
                value='ols',
                     ))
    ]
)

dashboard = vm.Dashboard(pages=[page_Korea_Magnitude, page_Korea_Month, page_Korea_Year,
                                page_World_Magnitude, page_World_Month, page_World_Year],
                         navigation=vm.Navigation(pages={"Korea" : ["Korea Magnitude","Korea Month","Korea Year"], 
                                                         "World" : ["World Magnitude", "World Month", "World Year"]}),
                        theme='vizro_light')

Vizro().build(dashboard).run()
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
